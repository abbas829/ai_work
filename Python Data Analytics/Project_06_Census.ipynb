# %% [markdown]
# # INDIA CENSUS 2011 DATASET

# %% [markdown]
# We will analyze this data using the Pandas DataFrame.

# %% [markdown]
#  ----

# %%
import pandas as pd

# %%
data = pd.read_csv(r"./data/06_Census_2011.csv")

# %%
data.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %% [markdown]
# ### 1. How will you hide the indexes of the dataframe.

# %%
# hide the indexes of the data frame by setting the index to None
data.set_index('District_code', inplace = True)

# %%
data.head()
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 4              JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 5              JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
# 4                 86236    51873         39839           12034
# 5                261724   161393        117677           43716
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# ...

# %% [markdown]
# ### 2. How can we set the caption / heading on the dataframe.

# %%
data.head(2)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
#
#                Secondary_Education  Higher_Education  Graduate_Education  \
# District_code
# 1                            74948             39709               21751
# 2                            66459             41367               27950
#
# ...

# %%
data.style.set_caption('India Census 2011 Dataset')
data.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
# ...

# %% [markdown]
# ### 3. Show the records related with the districts - New Delhi , Lucknow , Jaipur.

# %%
data[data['District_name'].isin(['New Delhi' , 'Lucknow' , 'Jaipur'])]
# Out:
#                   State_name District_name  Population     Male   Female  \
# District_code
# 94              NCT OF DELHI     New Delhi      142004    77942    64062
# 110                RAJASTHAN        Jaipur     6626178  3468507  3157671
# 157            UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 94               114179    59541         46940           12601
# 110             4300965  2464893       1714947          749946
# 157             3127260  1542806       1226399          316407
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 94                            121  ...        4852   2933        312    679
# 110                        744374  ...       12708  18782       1020  81079
# 157                        175578  ...       20493  23883       3877   4975
#
# ...

# %% [markdown]
# ### 4. Calculate state-wise :
# ### A. Total number of population.
# ### B. Total no. of population with different religions.

# %%
data.groupby('State_name')[['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']].sum().sort_values(by='Hindus')
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# LAKSHADWEEP                       1788     62268         317         8
# MIZORAM                          30136     14832      956331       286
# NAGALAND                        173054     48963     1739651      1890
# DAMAN AND DIU                   220150     19277        2820       172
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# MEGHALAYA                       342078    130399     2213027      3045
# SIKKIM                          352662      9867       60522      1868
# ARUNACHAL PRADESH               401876     27045      418732      3287
# CHANDIGARH                      852574     51447        8720    138329
# GOA                             963877    121564      366130      1473
# PONDICHERRY                    1089409     75556       78550       297
# ...

# %% [markdown]
# ### 5. How many Male Workers were there in Maharashtra state ?

# %%
data[data.State_name == 'MAHARASHTRA']['Male_Workers'].sum()
# Out:
# 32616875

# %% [markdown]
# ### 6. How to set a column as index of the dataframe ?

# %%
data.set_index('District_name')
# Out:
#                                             State_name  Population    Male  \
# District_name
# Kupwara                              JAMMU AND KASHMIR      870354  474190
# Badgam                               JAMMU AND KASHMIR      753745  398041
# Leh(Ladakh)                          JAMMU AND KASHMIR      133487   78971
# Kargil                               JAMMU AND KASHMIR      140802   77785
# Punch                                JAMMU AND KASHMIR      476835  251899
# ...                                                ...         ...     ...
# Mahe                                       PONDICHERRY       41816   19143
# Karaikal                                   PONDICHERRY      200222   97809
# Nicobars                   ANDAMAN AND NICOBAR ISLANDS       36842   20727
# North  AND Middle Andaman  ANDAMAN AND NICOBAR ISLANDS      105597   54861
# South Andaman              ANDAMAN AND NICOBAR ISLANDS      238142  127283
#
# ...

# %% [markdown]
# ### 7a. Add a Suffix to the column names.
# ### 7b. Add a Prefix to the column names.

# %%
data = data.add_prefix('leftone_')

# %%
data = data.add_suffix('_rightone_')

# %%
data.head()
# Out:
#               leftone_State_namerightone__rightone_  \
# District_code
# 1                                 JAMMU AND KASHMIR
# 2                                 JAMMU AND KASHMIR
# 3                                 JAMMU AND KASHMIR
# 4                                 JAMMU AND KASHMIR
# 5                                 JAMMU AND KASHMIR
#
#               leftone_District_namerightone__rightone_  \
# District_code
# 1                                              Kupwara
# 2                                               Badgam
# 3                                          Leh(Ladakh)
# 4                                               Kargil
# 5                                                Punch
#
#                leftone_Populationrightone__rightone_  \
# District_code
# 1                                             870354
# 2                                             753745
# 3                                             133487
# ...

# %% [markdown]
# ***
# ~~~
# Athuer: Tassawar Abbas
#
# Email: abbas829@gmail.com
#
# Github: github.com/abbas829
