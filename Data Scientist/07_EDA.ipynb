# %% [markdown]
# # **Exploratary Data Analysis**

# %% [markdown]
# Auther: Tassawar Abbas\
# Email: abbas829@gmail.com\
# Kaggle: https://www.kaggle.com/abbas829\
# gitub: https://www.github.com/abbas829

# %% [markdown]
# | Step                  | Description                                                                                           | Techniques                                                                                          |
# |-----------------------|-------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------|
# | 1. Data Collection    | Gather the dataset from various sources such as databases, files, APIs, etc.                         | - Importing data from CSV, Excel, SQL databases, etc.                                               |
# |                       |                                                                                                       | - Web scraping to collect data from websites.                                                        |
# |                       |                                                                                                       | - Using APIs to fetch data from online sources.                                                      |
# | 2. Data Inspection    | Examine the structure and properties of the dataset to gain an initial understanding.                 | - `head()` and `tail()` to view the first and last few rows.                                         |
# |                       |                                                                                                       | - `info()` to get a concise summary of the dataset including data types and missing values.          |
# |                       |                                                                                                       | - `describe()` to generate descriptive statistics for numerical columns.                             |
# |                       |                                                                                                       | - Visual inspection of data using simple print statements or display functions.                      |
# | 3. Data Cleaning      | Clean and preprocess the data to handle missing values, outliers, and inconsistencies.                | - Handling missing values using `fillna()`, `dropna()`, or imputation techniques.                     |
# |                       |                                                                                                       | - Outlier detection and treatment using statistical methods or domain knowledge.                      |
# |                       |                                                                                                       | - Standardizing or normalizing numerical features.                                                    |
# |                       |                                                                                                       | - Encoding categorical variables using one-hot encoding or label encoding.                           |
# | 4. Univariate Analysis| Analyze individual variables in the dataset to understand their distribution and characteristics.     | - Histograms, box plots, and density plots for continuous variables.                                 |
# |                       |                                                                                                       | - Bar plots, count plots, and pie charts for categorical variables.                                   |
# |                       |                                                                                                       | - Summary statistics such as mean, median, mode, variance, and skewness.                              |
# |                       |                                                                                                       | - Frequency tables and value counts for categorical variables.                                       |
# | 5. Bivariate Analysis | Explore relationships between pairs of variables to identify patterns and correlations.               | - Scatter plots, pair plots, and joint plots for continuous variables.                                |
# |                       |                                                                                                       | - Correlation matrices and heatmaps to visualize correlations between numerical variables.           |
# |                       |                                                                                                       | - Box plots, violin plots, and swarm plots to compare distributions across categories.               |
# |                       |                                                                                                       | - Cross-tabulation and contingency tables to analyze associations between categorical variables.     |
# | 6. Multivariate Analysis | Investigate interactions between multiple variables to uncover complex patterns and trends.      | - Dimensionality reduction techniques such as PCA or t-SNE.                                           |
# |                       |                                                                                                       | - Cluster analysis using techniques like K-means clustering or hierarchical clustering.               |
# |                       |                                                                                                       | - Advanced visualization techniques such as 3D plots, parallel coordinates, or Andrews curves.       |
# | 7. Feature Engineering| Create new features or transform existing ones to improve the predictive power of the dataset.       | - Feature scaling, transformation, and normalization.                                                |
# |                       |                                                                                                       | - Feature extraction from text, images, or other unstructured data using techniques like TF-IDF or PCA.|
# |                       |                                                                                                       | - Creation of interaction terms, polynomial features, or dummy variables.                             |
# | 8. Summary and Insights | Summarize key findings and insights from the EDA process to inform further analysis and modeling.   | - Documenting observations, trends, and anomalies discovered during analysis.                         |
# |                       |                                                                                                       | - Identifying potential data preprocessing or feature engineering steps.                              |
# |                       |                                                                                                       | - Communicating results effectively through reports, visualizations, or presentations.               |

# %% [markdown]
# ## **1.0. Importing the installed Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# ---

# %% [markdown]
# ## **1.2. Loading the dataset**

# %%
df = pd.read_csv("./data/data_cars.csv")
# To display the top 5 rows
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail(5)                        # To display the botton 5 rows
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **1.3. Checking the types of data**

# %% [markdown]
# Here we check for the datatypes because sometimes the MSRP or the price of the car would be stored as a string, if in that case, we have to convert that string to the integer data only then we can plot the data via a graph. Here, in this case, the data is already in integer format so nothing to worry.

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## **1.4. Dropping irrelevant columns**

# %% [markdown]
# This step is certainly needed in every EDA because sometimes there would be many columns that we never use in such cases dropping is the only solution. In this case, the columns such as Engine Fuel Type, Market Category, Vehicle style, Popularity, Number of doors, Vehicle Size doesn't make any sense to me so I just dropped for this instance.

# %%
df = df.drop([ 'Vehicle Size'], axis=1)
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **1.5. Renaming the columns**

# %% [markdown]
# In this instance, most of the column names are very confusing to read, so I just tweaked their column names. This is a good approach it improves the readability of the data set.

# %%
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
# 2       MANUAL  rear wheel drive              2.0
# 3       MANUAL  rear wheel drive              2.0
# 4       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  MPG-H  MPG-C  \
# 0  Factory Tuner,Luxury,High-Performance         Coupe     26     19
# 1                     Luxury,Performance   Convertible     28     19
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **1.6. Dropping the duplicate rows**

# %% [markdown]
# This is often a handy thing to do because a huge data set as in this case contains more than 10, 000 rows often have some duplicate data which might be disturbing, so here I remove all the duplicate value from the data-set.

# %%
df.shape
# Out:
# (11914, 15)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (726, 15)

# %% [markdown]
# Now let us remove the duplicate data because it's ok to remove them.

# %% [markdown]
# ## **1.7. Counting the number of Rows**

# %%
df.count()      # Used to count the number of rows
# Out:
# Make                11914
# Model               11914
# Year                11914
# Engine Fuel Type    11911
# HP                  11845
# Cylinders           11884
# Transmission        11914
# Drive Mode          11914
# Number of Doors     11908
# Market Category      8172
# Vehicle Style       11914
# MPG-H               11914
# MPG-C               11914
# Popularity          11914
# Price               11914
# dtype: int64

# %% [markdown]
# So seen above there are 11914 rows and we are removing 989 rows of duplicate data.

# %% [markdown]
# ## **1.8. Dropping the Duplicate Values**

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
# 2       MANUAL  rear wheel drive              2.0
# 3       MANUAL  rear wheel drive              2.0
# 4       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  MPG-H  MPG-C  \
# 0  Factory Tuner,Luxury,High-Performance         Coupe     26     19
# 1                     Luxury,Performance   Convertible     28     19
# ...

# %%
df.count()
# Out:
# Make                11188
# Model               11188
# Year                11188
# Engine Fuel Type    11185
# HP                  11119
# Cylinders           11158
# Transmission        11188
# Drive Mode          11188
# Number of Doors     11182
# Market Category      7823
# Vehicle Style       11188
# MPG-H               11188
# MPG-C               11188
# Popularity          11188
# Price               11188
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## **2.0. Dropping the missing or null values.**

# %% [markdown]
# This is mostly similar to the previous step but in here all the missing values are detected and are dropped later. Now, this is not a good approach to do so, because many people just replace the missing values with the mean or the average of that column, but in this case, I just dropped that missing values. This is because there is nearly 100 missing value compared to 10, 000 values this is a small number and this is negligible so I just dropped those values.

# %%
print(df.isnull().sum())
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine Fuel Type       3
# HP                    69
# Cylinders             30
# Transmission           0
# Drive Mode             0
# Number of Doors        6
# Market Category     3365
# Vehicle Style          0
# MPG-H                  0
# MPG-C                  0
# Popularity             0
# Price                  0
# dtype: int64

# %% [markdown]
# This is the reason in the above step while counting both Cylinders and Horsepower (HP) had 10856 and 10895 over 10925 rows.

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Make                7735
# Model               7735
# Year                7735
# Engine Fuel Type    7735
# HP                  7735
# Cylinders           7735
# Transmission        7735
# Drive Mode          7735
# Number of Doors     7735
# Market Category     7735
# Vehicle Style       7735
# MPG-H               7735
# MPG-C               7735
# Popularity          7735
# Price               7735
# dtype: int64

# %% [markdown]
# Now we have removed all the rows which contain the Null or N/A values (Cylinders and Horsepower (HP)).

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# Make                0
# Model               0
# Year                0
# Engine Fuel Type    0
# HP                  0
# Cylinders           0
# Transmission        0
# Drive Mode          0
# Number of Doors     0
# Market Category     0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## **3.0. Detecting Outliers**

# %% [markdown]
# An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It's often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in a less accurate model. Hence it's a good idea to remove them. The outlier detection and removing that I am going to perform is called IQR score technique. Often outliers can be seen with visualizations using a box plot. Shown below are the box plot of MSRP, Cylinders, Horsepower and EngineSize. Herein all the plots, you can find some points are outside the box they are none other than outliers. The technique of finding and removing outlier that I am performing in this assignment is taken help of a tutorial from[ towards data science](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba).

# %%
sns.boxplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(x=df['HP'])
# Out:
# <Axes: xlabel='HP'>

# %%
sns.boxplot(x=df['Cylinders'])
# Out:
# <Axes: xlabel='Cylinders'>

# %% [markdown]
# ## **4.0. Correlation of different features**

# %%
cor=df.corr(numeric_only=True)

# %% [markdown]
# ## 9. Plot different features against one another (scatter), against frequency (histogram)

# %% [markdown]
# ### Histogram
#
# Histogram refers to the frequency of occurrence of variables in an interval. In this case, there are mainly 10 different types of car manufacturing companies, but it is often important to know who has the most number of cars. To do this histogram is one of the trivial solutions which lets us know the total number of car manufactured by a different company.

# %% [markdown]
# ## **Price vs Make**

# %%
df.Make.value_counts().nlargest(15).plot(kind='bar', figsize=(10,5))
plt.title("Price of cars by make")
plt.ylabel('price of cars')
plt.xlabel('Make');

# %% [markdown]
# ## **Number of Cars vs Make**

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %% [markdown]
# ## **Data vs the Year**

# %%
df.Year.value_counts().plot(kind='pie')
plt.show()

# %%
df.Make.value_counts().nlargest(20).plot(kind='bar', figsize=(15, 10)) # figsize=(15, 10)
plt.title("Number of HP by car")
plt.ylabel('Number of HP')
plt.xlabel('Make');

# %% [markdown]
# ## **5.0. Heat Maps**

# %%
# Adjusting the Size of Figure
plt.figure(figsize=(10,5))
# Displaying the correlation using the Heap Map
sns.heatmap(cor,cmap="BrBG",annot=True) # Br: Brown. B: Blue, G: Green

#correlation
# Out:
# <Axes: >
