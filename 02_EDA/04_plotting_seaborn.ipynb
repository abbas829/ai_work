# %% [markdown]
# # Seaborn and plotting

# %% [markdown]
# Auther: Tassawar Abbas
#
# Email: abbas829@gmail.com
#
# [github](https://github.com/abbas829)

# %% [markdown]
# # Seaborn Library: A Comprehensive Guide
#
# Seaborn is a powerful Python data visualization library built on top of Matplotlib. It provides a high-level interface for drawing attractive statistical graphics. In this guide, we'll explore the various features of Seaborn, common commands in a table format, and useful tips and tricks for enhancing your data visualization workflow using Seaborn in VS Code.
#
# ## Table of Contents
#
# 1. [Introduction to Seaborn](#introduction-to-seaborn)
# 2. [Installation](#installation)
# 3. [Basic Plotting Commands](#basic-plotting-commands)
# 4. [Advanced Plotting Techniques](#advanced-plotting-techniques)
# 5. [Plotting Tips and Tricks](#plotting-tips-and-tricks)
# 6. [Integrating Seaborn with VS Code](#integrating-seaborn-with-vs-code)
# 7. [Conclusion](#conclusion)
#
# ## Introduction to Seaborn
#
# Seaborn is a Python data visualization library that is based on Matplotlib. It provides a high-level interface for drawing attractive statistical graphics. Seaborn is built on top of Matplotlib and closely integrated with Pandas data structures, making it ideal for working with datasets in a Pandas DataFrame.
#
# ## Installation
#
# You can install Seaborn using pip or conda.
#
# ### Using pip:
#
# ```bash
# pip install seaborn
# ```
#
# ### Using conda:
#
# ```bash
# conda install seaborn
# ```
#
# ## Basic Plotting Commands
#
# Below are some common Seaborn plotting commands:
#
# | Command                 | Description                         | Example                                       |
# |-------------------------|-------------------------------------|-----------------------------------------------|
# | `sns.scatterplot()`     | Create a scatter plot               | `sns.scatterplot(x='x_data', y='y_data', data=df)` |
# | `sns.lineplot()`        | Create a line plot                  | `sns.lineplot(x='x_data', y='y_data', data=df)`    |
# | ...                     | ...                                 | ...                                           |
#
# ## Advanced Plotting Techniques
#
# Seaborn provides advanced plotting techniques such as subplots, categorical plots, distribution plots, etc.
#
# ## Plotting Tips and Tricks
#
# - **Customizing Styles**: Seaborn provides several built-in themes and color palettes. Experiment with different styles to find the one that best suits your data.
# - **Adding Annotations**: Use annotations to highlight key points or add context to your plots. Annotations can be added using `plt.text()` or `ax.text()` functions.
# - **Fine-Tuning Axes**: Adjust axis limits, labels, and ticks to improve clarity and readability of your plots.
#
# ## Integrating Seaborn with VS Code
#
# You can integrate Seaborn with VS Code for a smoother workflow. This could include setting up Jupyter notebooks, using VS Code extensions for Markdown and Python, etc.
#
# ## Conclusion
#
# Seaborn is a powerful library for data visualization in Python. By following the tips and tricks mentioned in this guide, you can create beautiful and informative plots with ease.

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Important things for Plotting according to grammar of graphics
#
# 1. Data (df)
# 2. Types of plot?
# 3. x axis
# 4. y axis
# 5. grouping (hue/color) based on categorical variable
# 6. Size of the plot
# 7. Color palletes of the plot
# 8. Style of the plot
# 9. How do you interpret

# %%
# Data
df = sns.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# scatter plot
sns.scatterplot(data = df, x = 'age', y='fare', hue = 'sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# scatter plot
# scatter plto size of figure size
plt.figure(figsize=(8,4)) # a4 page size 16:9
sns.scatterplot(data = df, x = 'age', y='fare', hue = 'sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# scatter plot
# scatter plot size of figure size
plt.figure(figsize=(8,4)) # a4 page size 16:9

# change the scatter point colors
palette = {'male': 'green', 'female': 'red'}
sns.scatterplot(data=df, x='age', y='fare', hue='sex', palette=palette)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Fare')

# %%
# scatter plot
# scatter plot size of figure size
plt.figure(figsize=(8,4)) # a4 page size 16:9

# change the scatter point colors
palette = {'male': 'green', 'female': 'red'}
sns.scatterplot(data=df, x='age', y='fare', hue='sex', palette=palette)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs Fare')

# saving a plot 300dpi, 600dpi, 150dpi png
plt.savefig('./data/scatter_plot_zz.png', dpi=300)

# saving a plot in vector file such as svg
plt.savefig('./data/scatter_plot_zz.svg')

# %%
# style of a plot
sns.set_theme(style='darkgrid', font_scale=1.5, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(16,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'male': 'green', 'female': 'red'}
sns.scatterplot(data=df, x='age', y='fare', hue='sex', size='fare', palette=palette)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Fare')

# %% [markdown]
# Interpertation:
# 1. We have Age of passengers at x-axis and fare at y-axis
# 2. The scatter plot shows the relationship between age and fare of titanic passengers.
# 3. We further grouped the passenger by their genders such as male (Green points) and female (Red points).
# 4. Twpo male passengers gave the highest fare in titanic, and they might be travelling first class.
# 5. The olderst person at titanic is also a male having 80 years of age as shown in the scatter plot. (As shown in Figure. 1).

# %% [markdown]
# # Box plot

# %%
df['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.boxplot(data=df, x='sex', y='age', hue='class', palette=palette)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Box plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# %%
# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.boxenplot(data=df, x='sex', y='age', hue='class', palette=palette)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Boxen plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# change the x-ticks names
plt.xticks(ticks=[0, 1], labels=["Male", "Female"], rotation=0)
# Out:
# ([<matplotlib.axis.XTick at 0x26f198eddc0>,
#   <matplotlib.axis.XTick at 0x26f169a6ea0>],
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
# bar plot using seaborn

# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.barplot(data=df, x='sex', y='age', hue='class', palette=palette, capsize=0.1)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Bar plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# change the x-ticks names
plt.xticks(ticks=[0, 1], labels=["Male", "Female"], rotation=0)
# Out:
# ([<matplotlib.axis.XTick at 0x26f1999b1d0>,
#   <matplotlib.axis.XTick at 0x26f19967f50>],
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
# bar plot using seaborn

# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.violinplot(data=df, x='sex', y='age', hue='class', palette=palette)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Bar plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# change the x-ticks names
plt.xticks(ticks=[0, 1], labels=["Male", "Female"], rotation=0)
# Out:
# ([<matplotlib.axis.XTick at 0x26f1990b950>,
#   <matplotlib.axis.XTick at 0x26f1993eea0>],
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])
